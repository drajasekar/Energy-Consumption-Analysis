# %%
import glob
import pandas as pd
import json
import requests

# %%
df1 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\2021_final_bps_dataset.xlsx")
df2 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\2020_final_data_set.xlsx")
df3 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\2019_final_data_set.xlsx")
df4 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\2018_final_data_set.xlsx")
df5 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\2017_energy_consumption.xlsx")
df6 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\bps_2016_report_english.xlsx")
df7 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\bps_2015_report_english.xlsx")
df8 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\bps_2014_report_english.xlsx")                  
df9 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\bps_2013_report_english.xlsx")
df10 = pd.read_excel(r"C:\Users\Rajasekar\Downloads\bps_2012_report_english.xlsx")

# Concatenate DataFrames
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df8, df9, df10], axis=0)

# Display the first few rows of the concatenated DataFrame
df
# Out:
#           Sector     Subsector                            Organization  \
# 0      Municipal  Municipality  The Corporation of the City of Markham
# 1      Municipal  Municipality  The Corporation of the City of Markham
# 2      Municipal  Municipality  The Corporation of the City of Markham
# 3      Municipal  Municipality  The Corporation of the City of Markham
# 4      Municipal  Municipality  The Corporation of the City of Markham
# ...          ...           ...                                     ...
# 17975        NaN           NaN                                     NaN
# 17976        NaN           NaN                                     NaN
# 17977        NaN           NaN                                     NaN
# 17978        NaN           NaN                                     NaN
# 17979        NaN           NaN                                     NaN
#
#           Property Name Primary Property Type - Self Selected  \
# ...

# %%
# If there are any remaining duplicates based on "Sector," you can drop them
df =df.drop_duplicates(subset="Sector")
df.reset_index(drop=True, inplace=True)

# %%
# Accessing the first column name
first_column_name = df.columns[0]
print(first_column_name)

# Iterating over all column names
for column_name in df.columns:
    print(column_name)
# Out:
# Sector
# Sector
# Subsector
# Organization
# Property Name
# Primary Property Type - Self Selected
# Portfolio Manager Property ID
# Portfolio Manager Parent Property ID
# Parent Property Name
# Year Ending
# Address
# City
# Postal Code
# Property GFA - Self-Reported (m²)
# Number of Buildings
# Custom Property ID 1 - Name
# Custom Property ID 1 - Value
# Custom Property ID 2 - Name
# Custom Property ID 2 - Value
# Custom Property ID 3 - Name
# Custom Property ID 3 - Value
# Electricity Use - Grid Purchase (kWh)
# Electricity Use - Grid Purchase (GJ)
# Natural Gas Use (therms)
# Natural Gas Use (GJ)
# Fuel Oil #1 Use (GJ)
# Fuel Oil #2 Use (GJ)
# Fuel Oil #4 Use (GJ)
# Fuel Oil #5 & 6 Use (GJ)
# Diesel #2 Use (GJ)
# Kerosene Use (GJ)
# Propane Use (GJ)
# District Steam Use (GJ)
# District Hot Water Use (GJ)
# District Chilled Water Use (GJ)
# Wood Use (GJ)
# Site Energy Use (GJ)
# Source Energy Use (GJ)
# Site EUI (GJ/m²)
# Site EUI (ekWh/sqft)
# Source EUI (GJ/m²)
# ...

# %%
#Remove unnamed columns

# %%
# Remove unnamed columns
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# Display the cleaned DataFrame
print(df)
# Out:
#                                    Sector      Subsector  \
# 0                               Municipal   Municipality
# 1                         Public Hospital          Acute
# 2                           Postsecondary        College
# 3                           School Boards  School Boards
# 4                            School Board            NaN
# 5  Post-Secondary Educational Institution            NaN
# 6                                     NaN            NaN
#
#                              Organization  \
# 0  The Corporation of the City of Markham
# 1          The Hospital for Sick Children
# 2                          Boreal College
# 3            Algoma District School Board
# 4            Algoma District School Board
# 5                       Algoma University
# 6                                     NaN
#
#                             Property Name  \
# 0                        Fire Station #91
# 1  The Hospital for Sick Children - Annex
# ...

# %%
# Accessing the first column name
first_column_name = df.columns[0]
print(first_column_name)

# Iterating over all column names
for column_name in df.columns:
    print(column_name)
# Out:
# Sector
# Sector
# Subsector
# Organization
# Property Name
# Primary Property Type - Self Selected
# Portfolio Manager Property ID
# Portfolio Manager Parent Property ID
# Parent Property Name
# Year Ending
# Address
# City
# Postal Code
# Property GFA - Self-Reported (m²)
# Number of Buildings
# Custom Property ID 1 - Name
# Custom Property ID 1 - Value
# Custom Property ID 2 - Name
# Custom Property ID 2 - Value
# Custom Property ID 3 - Name
# Custom Property ID 3 - Value
# Electricity Use - Grid Purchase (kWh)
# Electricity Use - Grid Purchase (GJ)
# Natural Gas Use (therms)
# Natural Gas Use (GJ)
# Fuel Oil #1 Use (GJ)
# Fuel Oil #2 Use (GJ)
# Fuel Oil #4 Use (GJ)
# Fuel Oil #5 & 6 Use (GJ)
# Diesel #2 Use (GJ)
# Kerosene Use (GJ)
# Propane Use (GJ)
# District Steam Use (GJ)
# District Hot Water Use (GJ)
# District Chilled Water Use (GJ)
# Wood Use (GJ)
# Site Energy Use (GJ)
# Source Energy Use (GJ)
# Site EUI (GJ/m²)
# Site EUI (ekWh/sqft)
# Source EUI (GJ/m²)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187563 entries, 0 to 17979
# Data columns (total 97 columns):
#  #   Column                                                                   Non-Null Count   Dtype
# ---  ------                                                                   --------------   -----
#  0   Sector                                                                   100454 non-null  object
#  1   Subsector                                                                15232 non-null   object
#  2   Organization                                                             100454 non-null  object
#  3   Property Name                                                            15232 non-null   object
#  4   Primary Property Type - Self Selected                                    15232 non-null   object
#  5   Portfolio Manager Property ID                                            15232 non-null   float64
# ...

# %%
# Remove the 'Sub Sector' column
df = df.drop(columns=['Sub Sector'])

# %%
df
# Out:
#           Sector     Subsector                            Organization  \
# 0      Municipal  Municipality  The Corporation of the City of Markham
# 1      Municipal  Municipality  The Corporation of the City of Markham
# 2      Municipal  Municipality  The Corporation of the City of Markham
# 3      Municipal  Municipality  The Corporation of the City of Markham
# 4      Municipal  Municipality  The Corporation of the City of Markham
# ...          ...           ...                                     ...
# 17975        NaN           NaN                                     NaN
# 17976        NaN           NaN                                     NaN
# 17977        NaN           NaN                                     NaN
# 17978        NaN           NaN                                     NaN
# 17979        NaN           NaN                                     NaN
#
#           Property Name Primary Property Type - Self Selected  \
# ...

# %%
for column in df.columns:
    null_sum = df[column].isnull().sum()
    print(f"'{column}': {null_sum}")
# Out:
# 'Sector': 87109
# 'Subsector': 172331
# 'Organization': 87109
# 'Property Name': 172331
# 'Primary Property Type - Self Selected': 172331
# 'Portfolio Manager Property ID': 172331
# 'Portfolio Manager Parent Property ID': 172331
# 'Parent Property Name': 172331
# 'Year Ending': 172331
# 'Address': 87172
# 'City': 87110
# 'Postal Code': 87228
# 'Property GFA - Self-Reported (m²)': 172331
# 'Number of Buildings': 172331
# 'Custom Property ID 1 - Name': 172331
# 'Custom Property ID 1 - Value': 172331
# 'Custom Property ID 2 - Name': 172331
# 'Custom Property ID 2 - Value': 172331
# 'Custom Property ID 3 - Name': 172331
# 'Custom Property ID 3 - Value': 172331
# 'Electricity Use - Grid Purchase (kWh)': 172331
# 'Electricity Use - Grid Purchase (GJ)': 172331
# 'Natural Gas Use (therms)': 172331
# 'Natural Gas Use (GJ)': 172331
# 'Fuel Oil #1 Use (GJ)': 172331
# 'Fuel Oil #2 Use (GJ)': 172331
# 'Fuel Oil #4 Use (GJ)': 172331
# 'Fuel Oil #5 & 6 Use (GJ)': 172331
# ...

# %%
#Dropping Columns:If a column has a large number of missing values and is not crucial for your analysis, consider dropping it.
columns_to_drop = ['Subsector', 'FuelOil12_Unit', 'FuelOil46_Unit', 'Propane_Unit', 'Coal_Unit', 'Wood_Unit', 'DistrictHeating_Unit', 'DistrictCooling_Unit']
df_cleaned = df.drop(columns=columns_to_drop, axis=1)
#Dropping Rows:If a row has missing values in important columns, you might consider dropping those rows.
columns_to_check = ['Sector', 'Organization', 'City', 'Postal Code']
df_cleaned = df.dropna(subset=columns_to_check)

# %%
# Drop rows with a high number of missing values
threshold = 0.5  # Drop rows where more than 50% of values are missing
df_cleaned = df.dropna(thresh=len(df.columns) * (1 - threshold))

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187563 entries, 0 to 17979
# Data columns (total 96 columns):
#  #   Column                                                                   Non-Null Count   Dtype
# ---  ------                                                                   --------------   -----
#  0   Sector                                                                   100454 non-null  object
#  1   Subsector                                                                15232 non-null   object
#  2   Organization                                                             100454 non-null  object
#  3   Property Name                                                            15232 non-null   object
#  4   Primary Property Type - Self Selected                                    15232 non-null   object
#  5   Portfolio Manager Property ID                                            15232 non-null   float64
# ...

# %%
df.to_csv('GHGpreprocessed.csv', index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187563 entries, 0 to 17979
# Data columns (total 96 columns):
#  #   Column                                                                   Non-Null Count   Dtype
# ---  ------                                                                   --------------   -----
#  0   Sector                                                                   100454 non-null  object
#  1   Subsector                                                                15232 non-null   object
#  2   Organization                                                             100454 non-null  object
#  3   Property Name                                                            15232 non-null   object
#  4   Primary Property Type - Self Selected                                    15232 non-null   object
#  5   Portfolio Manager Property ID                                            15232 non-null   float64
# ...
